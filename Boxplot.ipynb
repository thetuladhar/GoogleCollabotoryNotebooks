# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os
from matplotlib.pyplot import figure

# %%
# !unzip MP_AlphaMesh.zip

# %%
len(np.load('/content/MP_AlphaMesh/A/0/0.npy'))
# Out:
# 1260

# %%
# Path for exported data, numpy arrays
Folder='MP_AlphaMesh'
letter=""

DATA_PATH = os.path.join(Folder) 

#Sorting to negate shuffling of dirs
dirs=os.listdir(Folder)
dirs.sort()

# %%
for word in dirs and if word!=".DS_store":
  print(word)
# Out:
#   File "<ipython-input-190-c1141e3aab41>", line 1
#     for word in dirs and if word!=".DS_store":
#                           ^
# SyntaxError: invalid syntax

# %%
 
pie = np.load(os.path.join(DATA_PATH,"A",str(0),"0.npy"))

# %%
pie[0]
# Out:
# -0.017297059297561646
